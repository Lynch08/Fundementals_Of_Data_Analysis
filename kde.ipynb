# %% [markdown]
# # Kernel Density Estimite

# %%
# Numerical Arrays
import numpy as np

# Plotting
import matplotlib.pyplot as plt

# Stats
import scipy.stats as stats

# Data frames
import pandas as pd

# Statistical Plot
import seaborn as sns

# %%
# Change the plot style
plt.style.use('fivethirtyeight')

# Change dedfault plot size
plt.rcParams["figure.figsize"] = (20,10)

# %% [markdown]
# # PDF: Probability Density Function

# %%
# Normal Distribution

def normalpdf(x, mu = 0.0, sigma = 1.0):
    """Calculates the PDF of a normal distribution"""
    numer = np.exp(-0.5 * np.square((x - mu) / sigma))
    denom = sigma * np.sqrt(2.0 * np.pi)
    return (numer / denom)

# %%
# test value
normalpdf(0.0)
# Out:
# 0.3989422804014327

# %%
# test values
normalpdf(np.array([-1.0, 0.0, 1.0]))
# Out:
# array([0.24197072, 0.39894228, 0.24197072])

# %%
# Some x Values
x = np.linspace(-5.0, 5.0 , 1000)

# Calculate our y values from x
y = normalpdf(x)

# Create a plot
fig, ax = plt.subplots()

# Plot the Values
ax.plot(x, y, 'r-')

# %%
# Create a plot
fig, ax = plt.subplots()

# Some x Values
x = np.linspace(-5.0, 5.0 , 1000)

# Calculate our y values from x (mu = 0.0 and sigma = sqrt(0.2))
y = normalpdf(x, 0.0, np.sqrt(0.2))
# Plot the values
ax.plot(x, y, 'b-')

# Calculate our y values from x (mu = 0.0 and sgma = 1.0)
y = normalpdf(x)
# Plot the values
ax.plot(x, y, 'r-')

# Calculate our y values from x (mu = 0.0 and sgma = 5.0)
y = normalpdf(x, sigma = np.sqrt(5.0))
# Plot the values
ax.plot(x, y, 'y-')

# Calculate our y values from x (mu = 2.0 and sgma = 0.5)
y = normalpdf(x, -2.0, np.sqrt(0.5))
# Plot the values
ax.plot(x, y, 'g-')

# %% [markdown]
# # Fill between in plots

# %%
# Some x Values
x = np.linspace(-5.0, 5.0 , 1000)

# Calculate our y values from x
y = normalpdf(x)

# Create a plot
fig, ax = plt.subplots()

# Plot the Values
ax.plot(x, y, 'k-')

# limit x values to -2.0 and 2.0
x = np.linspace(-2.0, 2.0 , 1000)

# Calculate the odf values
y = normalpdf(x)

# Fill between x axis and y - for for x values between -2.0 and 2.0
ax.fill_between(x, 0, y)

# Draw vertical lines
ax.axvline(-2.0, color = 'k', linestyle = ':')
ax.axvline(2.0, color = 'k', linestyle = ':')

# Draw some text
ax.text (0, 0.2, '~95%', horizontalalignment = 'center')
# Out:
# Text(0, 0.2, '~95%')

# %%
# Probability of value less than -2.0
stats.norm().cdf(-2.0)
# Out:
# 0.022750131948179195

# %%
# Probability of value less than 2.0
stats.norm().cdf(2.0)
# Out:
# 0.9772498680518208

# %%
# Probability of value between -2.0 and 2.0
stats.norm().cdf(2.0) - stats.norm().cdf(-2.0)
# Out:
# 0.9544997361036416

# %%
# Probability of value between -3.0 and 3.0
stats.norm().cdf(3.0) - stats.norm().cdf(-3.0)
# Out:
# 0.9973002039367398

# %% [markdown]
# # Some small PDFs

# %%
#Load Iris
df = pd.read_csv('IrisdataCSV.csv')
df
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Extract sepal lengths
sepdata = df['sepal length'].to_numpy()
sepdata
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#        6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#        6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#        6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#        6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#        6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#        7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#        7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#        6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])

# %%
# Just use first ten
sepdata = sepdata[:10]
sepdata
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9])

# %%
(high - low) * 0.5
# Out:
# 1.5

# %%
# Minimum and maximum values
low, high = sepdata.min(), sepdata.max()

#Create some space on the x axis
diff = high - low
low = low - diff
high = high + diff

# Some x Values
x = np.linspace(low, high , 1000)

# Create a plot
fig, ax = plt.subplots()

prev = 0 * x

for i in sepdata:
    # Calculate our y values from x
    y = normalpdf(x, mu=i, sigma = 0.1 )
    # Add the previous sums of the y values
    y = y + prev

    # Fill between x axis and y
    ax.fill_between(x, prev, y, alpha = 0.3)
    
    # Update the prev array
    prev = y

# Plot the Values
ax.plot(x, y, 'k-')

# %%
low, high = sepdata.min(), sepdata.max()
low, high
# Out:
# (4.4, 5.4)

# %%
sns.pairplot(data = df, hue = 'species')
