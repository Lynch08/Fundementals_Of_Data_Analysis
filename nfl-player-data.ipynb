# %% [markdown]
# # Playing with NFL Player data

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
nflCsv = pd.read_csv('nfl.csv')

# %%
print(nflCsv)

# %%
print (nflCsv.tail())
print (nflCsv.columns)

# %%
for index, row in nflCsv.iterrows():
    print (index, row)

# %%
#Read each row
print (nflCsv.iloc[0:4])

# %%
#Read each column
print(nflCsv[['player', 'pass_rating']])
# Out:
#                          player  pass_rating
# 0                 Aaron Rodgers         91.4
# 1                   Aaron Jones          0.0
# 2      Marquez Valdes-Scantling          0.0
# 3                 Davante Adams          0.0
# 4                  Jimmy Graham          0.0
# ...                         ...          ...
# 14537               Alec Ingold          0.0
# 14538             Derek Carrier          0.0
# 14539               Josh Palmer          0.0
# 14540               Gabe Nabers          0.0
# 14541                 K.J. Hill          0.0
#
# [14542 rows x 2 columns]

# %%
#Read each row
print (nflCsv.iloc[0:4])

# %%
#Read a specific location
print (nflCsv.iloc[0,3])

# %%
print(nflCsv.loc[nflCsv['pass_cmp'] > 46])
# Out:
#             game_id player_id pos              player team  pass_cmp  \
# 12781  202101100pit  RoetBe00  QB  Ben Roethlisberger  PIT        47
#
#        pass_att  pass_yds  pass_td  pass_int  ...     OT      Roof  Surface  \
# 12781        68       501        4         4  ...  False  outdoors    grass
#
#        Temperature  Humidity  Wind_Speed  Vegas_Line  Vegas_Favorite  \
# 12781           34        72           1        -5.0             PIT
#
#        Over_Under   game_date
# 12781        47.0  2021-01-10
#
# [1 rows x 69 columns] [0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14537    False
# 14538    False
# 14539    False
# 14540    False
# 14541    False
# Name: player, Length: 14542, dtype: bool]

# %%
# Adding a Column
nflCsv['%Pass_Comp'] = nflCsv['pass_cmp'] / nflCsv['pass_att'] *[100]

# %%
#Dropping a Column
nflCsv = nflCsv.drop(columns =  ['TYIS'])

# %%
#Verifing column was dropped
# Out:
#         game_id player_id pos                    player team  pass_cmp  \
# 0  201909050chi  RodgAa00  QB             Aaron Rodgers  GNB        18
# 1  201909050chi  JoneAa00  RB               Aaron Jones  GNB         0
# 2  201909050chi  ValdMa00  WR  Marquez Valdes-Scantling  GNB         0
# 3  201909050chi  AdamDa01  WR             Davante Adams  GNB         0
# 4  201909050chi  GrahJi00  TE              Jimmy Graham  GNB         0
#
#    pass_att  pass_yds  pass_td  pass_int  ...      Roof  Surface  Temperature  \
# 0        30       203        1         0  ...  outdoors    grass           65
# 1         0         0        0         0  ...  outdoors    grass           65
# 2         0         0        0         0  ...  outdoors    grass           65
# 3         0         0        0         0  ...  outdoors    grass           65
# 4         0         0        0         0  ...  outdoors    grass           65
#
#    Humidity  Wind_Speed  Vegas_Line  Vegas_Favorite  Over_Under   game_date  \
# 0        69          10        -3.5             CHI        47.0  2019-09-05
# 1        69          10        -3.5             CHI        47.0  2019-09-05
# 2        69          10        -3.5             CHI        47.0  2019-09-05
# 3        69          10        -3.5             CHI        47.0  2019-09-05
# 4        69          10        -3.5             CHI        47.0  2019-09-05
#
#    %Pass_Comp
# 0        60.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 70 columns]

# %%
#Another way to add a column
nflCsv['incomplete'] = nflCsv.iloc[:, 5:7].sum(axis = 1)

# %%
nflCsv.head(5)
# Out:
#         game_id player_id pos                    player team  pass_cmp  \
# 0  201909050chi  RodgAa00  QB             Aaron Rodgers  GNB        18
# 1  201909050chi  JoneAa00  RB               Aaron Jones  GNB         0
# 2  201909050chi  ValdMa00  WR  Marquez Valdes-Scantling  GNB         0
# 3  201909050chi  AdamDa01  WR             Davante Adams  GNB         0
# 4  201909050chi  GrahJi00  TE              Jimmy Graham  GNB         0
#
#    pass_att  pass_yds  pass_td  pass_int  ...  Surface  Temperature  Humidity  \
# 0        30       203        1         0  ...    grass           65        69
# 1         0         0        0         0  ...    grass           65        69
# 2         0         0        0         0  ...    grass           65        69
# 3         0         0        0         0  ...    grass           65        69
# 4         0         0        0         0  ...    grass           65        69
#
#    Wind_Speed  Vegas_Line  Vegas_Favorite  Over_Under   game_date  %Pass_Comp  \
# 0          10        -3.5             CHI        47.0  2019-09-05        60.0
# 1          10        -3.5             CHI        47.0  2019-09-05         NaN
# 2          10        -3.5             CHI        47.0  2019-09-05         NaN
# 3          10        -3.5             CHI        47.0  2019-09-05         NaN
# 4          10        -3.5             CHI        47.0  2019-09-05         NaN
#
#    incomplete
# 0          48
# 1           0
# 2           0
# 3           0
# 4           0
#
# [5 rows x 71 columns]
