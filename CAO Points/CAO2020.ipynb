# %% [markdown]
# <br>
#
# ## 2020 CAO Points

# %%
# Data Frames
import pandas as pd
from collections import namedtuple
import requests, PyPDF2
# Regular Expressions
import re

# Convenient HTTP Requests.
import requests as rq

# dates and times
import datetime as dt

# For downloading
import urllib.request as urlrq

# %% [markdown]
# ##### Steps to reproduce
#
# 1. Download original PDF
# 2. Open PDF using Microsoft Word
# 3. Save MS Words convered PDF in docx format
# 4. Re-save Word Doc for editing
# 5. Delete Headers and footers
# 6. Delete preamble and intro on first page
# 7. Select all and copy
# 8. Paste into VS Code
# 9. Remove HEI Name lines and black lines
# 10. Change column heading "Course and intitution" to COURSE
# 11. Change Backticks to apostrophes
# 12. Replace double tab cahracter on line 28 with single tab
# 13. Delete tabs at end of lines 604, 670, 700, 701, 793 and 830

# %%
# Get Current date and time.
now = dt.datetime.now()

# Format as string
nowstr = now.strftime('%Y%m%d_%H%M%S')

# %%
#Create file path for original data
path = 'data/cao2020_'+ nowstr + '.xlsx'

# %%
# Save original file to disk
urlrq.urlretrieve('http://www2.cao.ie/points/CAOPointsCharts2020.xlsx', path)
# Out:
# ('data/cao2020_20211109_215503.xlsx',
#  <http.client.HTTPMessage at 0x1a9d07e4310>)

# %% [markdown]
# <br>
#
# ## Load Spreadsheet using Pandas

# %%
# Download and parse the excel spreadsheet
df = pd.read_excel('http://www2.cao.ie/points/CAOPointsCharts2020.xlsx', skiprows = 10)

# %%
df
# Out:
#                        CATEGORY (i.e.ISCED description)  \
# 0                           Business and administration
# 1                         Humanities (except languages)
# 2                                                  Arts
# 3                                                  Arts
# 4                                                  Arts
# ...                                                 ...
# 1459                       Manufacturing and processing
# 1460  Information and Communication Technologies (ICTs)
# 1461  Information and Communication Technologies (ICTs)
# 1462                                  Personal services
# 1463                 Engineering and engineering trades
#
#                                            COURSE TITLE COURSE CODE2  \
# 0                                International Business        AC120
# 1                                          Liberal Arts        AC137
# 2      First Year Art & Design (Common Entry,portfolio)        AD101
# ...

# %%
# Spot Check Random Row
df.iloc[753]
# Out:
# CATEGORY (i.e.ISCED description)          Engineering and engineering trades
# COURSE TITLE                        Road Transport Technology and Management
# COURSE CODE2                                                           LC286
# R1 POINTS                                                                264
# R1 Random *                                                              NaN
# R2 POINTS                                                                NaN
# R2 Random*                                                               NaN
# EOS                                                                      264
# EOS Random *                                                             NaN
# EOS Mid-point                                                            360
# LEVEL                                                                      7
# HEI                                         Limerick Institute of Technology
# ...

# %%
# Spot Check End of Data
df.iloc[-1]
# Out:
# CATEGORY (i.e.ISCED description)          Engineering and engineering trades
# COURSE TITLE                        Mechanical and Manufacturing Engineering
# COURSE CODE2                                                           WD230
# R1 POINTS                                                                253
# R1 Random *                                                              NaN
# R2 POINTS                                                                NaN
# R2 Random*                                                               NaN
# EOS                                                                      253
# EOS Random *                                                             NaN
# EOS Mid-point                                                            369
# LEVEL                                                                      8
# HEI                                        Waterford Institute of Technology
# ...

# %%
#Create file path for PANDAS data
path = 'data/cao2020_'+ nowstr + '.csv'

# %%
# Save pandas data frame to disk
df.to_csv(path)

# %% [markdown]
# <br>
#
# Concatonate and Join
